# %%
pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from opencv-contrib-python) (1.26.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\Practical 01\IM\Scripts\python.exe -m pip install --upgrade pip

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from opencv-python) (1.26.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\Practical 01\IM\Scripts\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\Practical 01\IM\Scripts\python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %%
print(cv2.__version__)
# Out:
# 4.9.0

# %%
img = cv2.imread(r'C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\Practical 01\IM\img1.jpg')
plt.imshow(img)

# %%
grey = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)
plt.imshow(grey)

# %%
blurred = cv2.GaussianBlur(grey , (5,5), 0)
plt.imshow(blurred)

# %%
edges = cv2.Canny(blurred, 50 ,150)
plt.imshow(edges)

# %%
_, thresh = cv2.threshold(grey, 127, 255, cv2.THRESH_BINARY)
plt.imshow(thresh)

# %%
#find contours in the binary timage
contours,_ = cv2.findContours(thresh,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
cv2.drawContours(img, contours, -1, (0, 255, 0), 2)
# Out:
# array([[[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        ...,
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]]], dtype=uint8)

# %%
import cv2

def find_triangles(image_path):
    # Read the image
    img = cv2.imread(image_path)

    # Convert the image to grayscale
    grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply GaussianBlur to reduce noise and help contour detection
    blurred = cv2.GaussianBlur(grey, (7, 7), 0)

    # Apply Canny edge detection
    edges = cv2.Canny(blurred, 30, 150)

    # Find contours in the edged image
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Create a copy of the original image to draw on
    img_with_boxes = img.copy()

    # Iterate through the contours
    for contour in contours:
        # Approximate the contour to a polygon
        epsilon = 0.04 * cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, epsilon, True)

        # If the polygon has 3 vertices, it's a triangle
        if len(approx) == 3:
            # Draw a bounding box around the triangle (in red)
            x, y, w, h = cv2.boundingRect(contour)
            cv2.rectangle(img_with_boxes, (x, y), (x + w, y + h), (0, 0, 255), 2)

    # Display the result 
    cv2.imshow('Triangles with Bounding Boxes', img_with_boxes)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
find_triangles(r'C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\Practical 01\IM\img1.jpg')

# %%
pip install face_recognition opencv-python
# Out:
# Requirement already satisfied: face_recognition in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (1.3.0)
# Requirement already satisfied: opencv-python in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (4.9.0.80)
# Requirement already satisfied: face-recognition-models>=0.3.0 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: Click>=6.0 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from face_recognition) (8.1.7)
# Requirement already satisfied: dlib>=19.7 in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from face_recognition) (19.24.1)
# Requirement already satisfied: numpy in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from face_recognition) (1.26.3)
# Requirement already satisfied: Pillow in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from face_recognition) (10.2.0)
# Requirement already satisfied: colorama in c:\users\basuru yasaruwan\contacts\desktop\ipcv practicals\practical 01\im\lib\site-packages (from Click>=6.0->face_recognition) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

def find_triangles(image_path):
    # Read the image
    img = cv2.imread(image_path)

    # Convert the image to grayscale
    grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply GaussianBlur to reduce noise and help contour detection
    blurred = cv2.GaussianBlur(grey, (7, 7), 0)

    # Apply Canny edge detection
    edges = cv2.Canny(blurred, 30, 150)

    # Find contours in the edged image
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Create a copy of the original image to draw on
    img_with_boxes = img.copy()

    # Iterate through the contours
    for contour in contours:
        # Approximate the contour to a polygon
        epsilon = 0.04 * cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, epsilon, True)

        # If the polygon has 3 vertices, it's a triangle
        if len(approx) == 3:
            # Draw a bounding box around the triangle (in red)
            x, y, w, h = cv2.boundingRect(contour)
            cv2.rectangle(img_with_boxes, (x, y), (x + w, y + h), (0, 0, 255), 2)

    # Display the result 
    cv2.imshow('Triangles with Bounding Boxes', img_with_boxes)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
find_triangles(r'C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\Practical 01\IM\img1.jpg')

# %%
def find_square(image_path, resize_factor=1.0):
    img = cv2.imread(image_path)
    
    # Resize the image if a resize_factor is provided
    if resize_factor != 1.0:
        img = cv2.resize(img, None, fx=resize_factor, fy=resize_factor)

    grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(grey, (7, 7), 0)
    edges = cv2.Canny(blurred, 30, 150)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    for contour in contours:
        approx = cv2.approxPolyDP(contour, 0.02 * cv2.arcLength(contour, True), True)
        if len(approx) == 4 and cv2.isContourConvex(approx):
            # Check if opposite sides are approximately parallel
            side1 = np.linalg.norm(approx[0] - approx[1])
            side2 = np.linalg.norm(approx[2] - approx[3])
            side3 = np.linalg.norm(approx[1] - approx[2])
            side4 = np.linalg.norm(approx[3] - approx[0])

            diagonal1 = np.linalg.norm(approx[0] - approx[2])
            diagonal2 = np.linalg.norm(approx[1] - approx[3])

            # Check for right angles and parallel sides
            if (
                abs(side1 - side3) < 0.1 * side1
                and abs(side2 - side4) < 0.1 * side2
                and abs(diagonal1 - diagonal2) < 0.1 * diagonal1
            ):
                cv2.drawContours(img, [approx], 0, (0, 255, 0), 2)

    cv2.imshow('Square with Bounding Boxes', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Example usage with resizing by a factor of 0.5 (you can adjust as needed)
image_path = r'C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\Practical 01\IM\img1.jpg'
find_square(image_path, resize_factor=0.5)

# %%
def find_rectangles(image_path, resize_factor=1.0):
    img = cv2.imread(image_path)
    
    # Resize the image if a resize_factor is provided
    if resize_factor != 1.0:
        img = cv2.resize(img, None, fx=resize_factor, fy=resize_factor)

    grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(grey, (7, 7), 0)
    edges = cv2.Canny(blurred, 30, 150)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    for contour in contours:
        approx = cv2.approxPolyDP(contour, 0.02 * cv2.arcLength(contour, True), True)
        if len(approx) == 4 and cv2.isContourConvex(approx):
            # Check if opposite sides are approximately parallel
            side1 = np.linalg.norm(approx[0] - approx[1])
            side2 = np.linalg.norm(approx[1] - approx[2])
            side3 = np.linalg.norm(approx[2] - approx[3])
            side4 = np.linalg.norm(approx[3] - approx[0])

            # Check for right angles and non-equal sides
            if (
                abs(side1 - side3) < 0.2 * side1
                and abs(side2 - side4) < 0.2 * side2
                and not np.isclose(side1, side2)  # Exclude squares
            ):
                cv2.drawContours(img, [approx], 0, (0, 255, 0), 2)

    cv2.imshow('Rectangles with Bounding Boxes', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Example usage with resizing by a factor of 0.5 (you can adjust as needed)
image_path = r'C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\Practical 01\IM\img1.jpg'
find_rectangles(image_path, resize_factor=0.5)

# %%
def find_full_circles(image_path, resize_factor=1.0):
    img = cv2.imread(image_path)

    # Resize the image if a resize_factor is provided
    if resize_factor != 1.0:
        img = cv2.resize(img, None, fx=resize_factor, fy=resize_factor)

    grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(grey, (7, 7), 0)
    circles = cv2.HoughCircles(
        blurred,
        cv2.HOUGH_GRADIENT,
        dp=1,
        minDist=50,
        param1=50,  # Adjust as needed
        param2=30,  # Adjust as needed
        minRadius=10,
        maxRadius=50
    )

    if circles is not None:
        circles = np.uint16(np.around(circles))
        for i in circles[0, :]:
            center = (i[0], i[1])
            radius = i[2]

            # Create a circular mask
            mask = np.zeros_like(grey)
            cv2.circle(mask, center, radius, 255, thickness=cv2.FILLED)

            # Find contours within the circular mask
            contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

            # Calculate circularity by comparing the area of the contour to the area of the circle
            if len(contours) > 0:
                contour_area = cv2.contourArea(contours[0])
                circle_area = np.pi * radius**2

                # Set a circularity threshold (adjust as needed)
                circularity_threshold = 0.85

                if contour_area / circle_area > circularity_threshold:
                    # draw the outer circle
                    cv2.circle(img, center, radius, (0, 255, 0), 2)
                    # draw the center of the circle
                    cv2.circle(img, center, 2, (0, 0, 255), 3)

    cv2.imshow('Full Circles with Bounding Boxes', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Example usage with resizing by a factor of 0.5 (you can adjust as needed)
image_path = r'C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\Practical 01\IM\img1.jpg'
find_full_circles(image_path, resize_factor=0.5)

# %%
def count_shapes(image_path):
    img = cv2.imread(image_path)

    # Convert the image to grayscale
    grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply GaussianBlur to reduce noise and help contour detection
    blurred = cv2.GaussianBlur(grey, (7, 7), 0)

    # Apply Canny edge detection
    edges = cv2.Canny(blurred, 30, 150)

    # Find contours in the edged image
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Initialize counters
    triangle_count = 0
    square_count = 0
    circle_count = 0

    # Iterate through the contours
    for contour in contours:
        # Approximate the contour to a polygon
        epsilon = 0.04 * cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, epsilon, True)

        # If the polygon has 3 vertices, it's a triangle
        if len(approx) == 3:
            triangle_count += 1
        elif len(approx) == 4 and cv2.isContourConvex(approx):
            # Check if it's a square
            side1 = np.linalg.norm(approx[0] - approx[1])
            side2 = np.linalg.norm(approx[2] - approx[3])
            side3 = np.linalg.norm(approx[1] - approx[2])
            side4 = np.linalg.norm(approx[3] - approx[0])

            diagonal1 = np.linalg.norm(approx[0] - approx[2])
            diagonal2 = np.linalg.norm(approx[1] - approx[3])

            if (
                abs(side1 - side3) < 0.1 * side1
                and abs(side2 - side4) < 0.1 * side2
                and abs(diagonal1 - diagonal2) < 0.1 * diagonal1
            ):
                square_count += 1
        else:
            # Check if it's a circle
            center, radius = cv2.minEnclosingCircle(contour)
            circularity = 4 * np.pi * cv2.contourArea(contour) / (cv2.arcLength(contour, True) ** 2)

            if circularity > 0.85:
                circle_count += 1

    # Print the counts
    print(f'Triangles: {triangle_count}')
    print(f'Squares: {square_count}')
    print(f'Circles: {circle_count}')

# Example usage
image_path = r'C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\Practical 01\IM\img1.jpg'
count_shapes(image_path)
# Out:
# Triangles: 1
# Squares: 1
# Circles: 1
